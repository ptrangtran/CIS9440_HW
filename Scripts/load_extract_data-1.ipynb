# %%
# !pip install azure-storage-blob
# !pip install boto3
# Out:
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.19.1-py3-none-any.whl (394 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.5/394.5 kB 4.1 MB/s eta 0:00:00
# Collecting azure-core<2.0.0,>=1.28.0 (from azure-storage-blob)
#   Downloading azure_core-1.30.1-py3-none-any.whl (193 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.4/193.4 kB 6.6 MB/s eta 0:00:00
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (42.0.5)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from azure-storage-blob) (4.11.0)
# Collecting isodate>=0.6.1 (from azure-storage-blob)
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.7/41.7 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.21.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.10/dist-packages (from cryptography>=2.1.4->azure-storage-blob) (1.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-blob) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.21.0->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2024.2.2)
# Installing collected packages: isodate, azure-core, azure-storage-blob
# Successfully installed azure-core-1.30.1 azure-storage-blob-12.19.1 isodate-0.6.1
# Collecting boto3
#   Downloading boto3-1.34.97-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 2.8 MB/s eta 0:00:00
# Collecting botocore<1.35.0,>=1.34.97 (from boto3)
#   Downloading botocore-1.34.97-py3-none-any.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 25.0 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.11.0,>=0.10.0 (from boto3)
#   Downloading s3transfer-0.10.1-py3-none-any.whl (82 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.2/82.2 kB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.97->boto3) (2.8.2)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.35.0,>=1.34.97->boto3) (2.0.7)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.35.0,>=1.34.97->boto3) (1.16.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.34.97 botocore-1.34.97 jmespath-1.0.1 s3transfer-0.10.1

# %%
import json
import boto3
from azure.storage.blob import BlobServiceClient, BlobClient, ContainerClient
from io import StringIO
import pandas as pd
import numpy as np
import requests

# %%
# URL to get the data
url = "https://data.cdc.gov/api/views/hn4x-zwk7/rows.csv?accessType=DOWNLOAD"

# Read the data from the CSV URL
df_raw = pd.read_csv(url)

# Convert DataFrame to CSV string
csv_data = df_raw.to_csv(index=False)

# %%
# Azure Functions
def azure_upload_blob(connect_str, container_name, blob_name, data):
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    blob_client.upload_blob(data, overwrite=True)
    print(f"Uploaded to Azure Blob: {blob_name}")

def azure_download_blob(connect_str, container_name, blob_name):
    blob_service_client = BlobServiceClient.from_connection_string(connect_str)
    blob_client = blob_service_client.get_blob_client(container=container_name, blob=blob_name)
    download_stream = blob_client.download_blob()
    return download_stream.readall()

# %%
df_raw.head()
# Out:
#    YearStart  YearEnd LocationAbbr LocationDesc  \
# 0       2020     2020           US     National
# 1       2014     2014           GU         Guam
# 2       2013     2013           US     National
# 3       2013     2013           US     National
# 4       2015     2015           US     National
#
#                                    Datasource                    Class  \
# 0  Behavioral Risk Factor Surveillance System        Physical Activity
# 1  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 2  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 3  Behavioral Risk Factor Surveillance System  Obesity / Weight Status
# 4  Behavioral Risk Factor Surveillance System        Physical Activity
#
#                           Topic  \
# 0  Physical Activity - Behavior
# 1       Obesity / Weight Status
# 2       Obesity / Weight Status
# 3       Obesity / Weight Status
# 4  Physical Activity - Behavior
#
#                                             Question  Data_Value_Unit  \
# 0  Percent of adults who engage in no leisure-tim...              NaN
# 1  Percent of adults aged 18 years and older who ...              NaN
# 2  Percent of adults aged 18 years and older who ...              NaN
# 3  Percent of adults aged 18 years and older who ...              NaN
# 4  Percent of adults who achieve at least 300 min...              NaN
#
#   Data_Value_Type  ...              GeoLocation  ClassID TopicID QuestionID  \
# 0           Value  ...                      NaN       PA     PA1       Q047
# 1           Value  ...  (13.444304, 144.793731)      OWS    OWS1       Q036
# 2           Value  ...                      NaN      OWS    OWS1       Q036
# 3           Value  ...                      NaN      OWS    OWS1       Q037
# 4           Value  ...                      NaN       PA     PA1       Q045
#
#    DataValueTypeID  LocationID  StratificationCategory1       Stratification1  \
# 0            VALUE          59           Race/Ethnicity              Hispanic
# 1            VALUE          66                Education  High school graduate
# 2            VALUE          59                   Income     $50,000 - $74,999
# 3            VALUE          59                   Income     Data not reported
# 4            VALUE          59                   Income     Less than $15,000
#
#   StratificationCategoryId1 StratificationID1
# 0                      RACE           RACEHIS
# 1                       EDU         EDUHSGRAD
# 2                       INC           INC5075
# 3                       INC             INCNR
# 4                       INC         INCLESS15
#
# [5 rows x 33 columns]

# %%
#remove columns
remove_columns = [
    'Data_Value_Unit',
    'Data_Value_Type',
    'Data_Value_Footnote_Symbol',
    'Data_Value_Footnote',
    'Total',
    'Age(years)',
    'Education',
    'Gender',
    'Income',
    'Race/Ethnicity',
    'DataValueTypeID',
    'Data_Value_Alt',
    'TopicID',
    'Class',
    'Datasource',
    'Sample_Size',
    'Low_Confidence_Limit',
]
df = df_raw.drop(columns=remove_columns)

# %%
#rename columns
df = df.rename(columns= {'LocationAbbr': 'StateAbbr', 'LocationDesc': 'State','ClassID': 'TopicID', 'StratificationCategoryId1': 'StratificationCategory1',
                           'StratificationCategory1':'StratificationCategory2', 'Stratification1': 'Stratification',
                          'StratificationID1': 'StratificationID'})

# %%
#drop all columns with NaN values
df = df.dropna()

# %%
df['Latitude'] = df['GeoLocation'].apply(lambda x: float(x.split(',')[0].strip('()')))
df['Longitude'] = df['GeoLocation'].apply(lambda x: float(x.split(',')[1].strip('()')))
df = df.drop(columns='GeoLocation')

# %%
df.head(10)
# Out:
#     YearStart  YearEnd StateAbbr                 State  \
# 1        2014     2014        GU                  Guam
# 5        2015     2015        GU                  Guam
# 6        2012     2012        WY               Wyoming
# 7        2012     2012        DC  District of Columbia
# 8        2015     2015        PR           Puerto Rico
# 9        2011     2011        AL               Alabama
# 10       2015     2015        GU                  Guam
# 11       2015     2015        RI          Rhode Island
# 13       2012     2012        WY               Wyoming
# 14       2020     2020        DE              Delaware
#
#                            Topic  \
# 1        Obesity / Weight Status
# 5   Physical Activity - Behavior
# 6        Obesity / Weight Status
# 7        Obesity / Weight Status
# 8   Physical Activity - Behavior
# 9        Obesity / Weight Status
# 10  Physical Activity - Behavior
# 11       Obesity / Weight Status
# 13  Physical Activity - Behavior
# 14  Physical Activity - Behavior
#
#                                              Question  Data_Value  \
# 1   Percent of adults aged 18 years and older who ...        29.3
# 5   Percent of adults who achieve at least 150 min...        27.4
# 6   Percent of adults aged 18 years and older who ...        48.5
# 7   Percent of adults aged 18 years and older who ...        31.6
# 8   Percent of adults who engage in no leisure-tim...        38.1
# 9   Percent of adults aged 18 years and older who ...        35.2
# 10  Percent of adults who engage in no leisure-tim...        30.5
# 11  Percent of adults aged 18 years and older who ...        40.2
# 13  Percent of adults who engage in no leisure-tim...        32.3
# 14  Percent of adults who engage in no leisure-tim...        15.3
#
#     High_Confidence_Limit  TopicID QuestionID  LocationID  \
# 1                     33.3     OWS       Q036          66
# 5                     38.5      PA       Q044          66
# 6                     64.9     OWS       Q037          56
# 7                     40.4     OWS       Q036          11
# 8                     43.8      PA       Q047          72
# 9                     40.0     OWS       Q036           1
# 10                    35.6      PA       Q047          66
# 11                    47.4     OWS       Q037          44
# 13                    39.8      PA       Q047          56
# 14                    30.6      PA       Q047          10
#
#    StratificationCategory2                 Stratification  \
# 1                Education           High school graduate
# 5           Race/Ethnicity                       Hispanic
# 6           Race/Ethnicity  American Indian/Alaska Native
# 7                Education          Less than high school
# 8                   Income              $25,000 - $34,999
# 9              Age (years)                        25 - 34
# 10               Education           High school graduate
# 11          Race/Ethnicity                       Hispanic
# 13                  Income              Less than $15,000
# 14          Race/Ethnicity                          Asian
#
#    StratificationCategory1 StratificationID   Latitude   Longitude
# 1                      EDU        EDUHSGRAD  13.444304  144.793731
# 5                     RACE          RACEHIS  13.444304  144.793731
# 6                     RACE          RACENAA  43.235541 -108.109830
# 7                      EDU            EDUHS  38.890371  -77.031961
# 8                      INC          INC2535  18.220833  -66.590149
# 9                    AGEYR        AGEYR2534  32.840571  -86.631861
# 10                     EDU        EDUHSGRAD  13.444304  144.793731
# 11                    RACE          RACEHIS  41.708280  -71.522470
# 13                     INC        INCLESS15  43.235541 -108.109830
# 14                    RACE          RACEASN  39.008831  -75.577741

# %%
column_order = [
    'YearStart', 'YearEnd',
    'LocationID','StateAbbr', 'State', 'Latitude', 'Longitude',
    'TopicID', 'Topic','QuestionID', 'Question',
    'StratificationID', 'StratificationCategory1', 'StratificationCategory2', 'Stratification' ,
    'Data_Value','High_Confidence_Limit'
]
df = df.reindex(columns=column_order)

# %%
df = df.iloc[:, :-1]

# %%
df.head(20)
# Out:
#     YearStart  YearEnd  LocationID StateAbbr                 State   Latitude  \
# 1        2014     2014          66        GU                  Guam  13.444304
# 5        2015     2015          66        GU                  Guam  13.444304
# 6        2012     2012          56        WY               Wyoming  43.235541
# 7        2012     2012          11        DC  District of Columbia  38.890371
# 8        2015     2015          72        PR           Puerto Rico  18.220833
# 9        2011     2011           1        AL               Alabama  32.840571
# 10       2015     2015          66        GU                  Guam  13.444304
# 11       2015     2015          44        RI          Rhode Island  41.708280
# 13       2012     2012          56        WY               Wyoming  43.235541
# 14       2020     2020          10        DE              Delaware  39.008831
# 17       2015     2015          66        GU                  Guam  13.444304
# 18       2011     2011          44        RI          Rhode Island  41.708280
# 20       2017     2017          34        NJ            New Jersey  40.130570
# 22       2017     2017          53        WA            Washington  47.522279
# 24       2015     2015          72        PR           Puerto Rico  18.220833
# 26       2014     2014          72        PR           Puerto Rico  18.220833
# 27       2014     2014          66        GU                  Guam  13.444304
# 29       2015     2015          72        PR           Puerto Rico  18.220833
# 31       2015     2015          72        PR           Puerto Rico  18.220833
# 32       2020     2020          23        ME                 Maine  45.254229
#
#      Longitude TopicID                             Topic QuestionID  \
# 1   144.793731     OWS           Obesity / Weight Status       Q036
# 5   144.793731      PA      Physical Activity - Behavior       Q044
# 6  -108.109830     OWS           Obesity / Weight Status       Q037
# 7   -77.031961     OWS           Obesity / Weight Status       Q036
# 8   -66.590149      PA      Physical Activity - Behavior       Q047
# 9   -86.631861     OWS           Obesity / Weight Status       Q036
# 10  144.793731      PA      Physical Activity - Behavior       Q047
# 11  -71.522470     OWS           Obesity / Weight Status       Q037
# 13 -108.109830      PA      Physical Activity - Behavior       Q047
# 14  -75.577741      PA      Physical Activity - Behavior       Q047
# 17  144.793731     OWS           Obesity / Weight Status       Q036
# 18  -71.522470     OWS           Obesity / Weight Status       Q036
# 20  -74.273691      PA      Physical Activity - Behavior       Q046
# 22 -120.470011      FV  Fruits and Vegetables - Behavior       Q018
# 24  -66.590149     OWS           Obesity / Weight Status       Q037
# 26  -66.590149     OWS           Obesity / Weight Status       Q037
# 27  144.793731     OWS           Obesity / Weight Status       Q036
# 29  -66.590149      PA      Physical Activity - Behavior       Q047
# 31  -66.590149     OWS           Obesity / Weight Status       Q036
# 32  -68.985031      PA      Physical Activity - Behavior       Q047
#
#                                              Question StratificationID  \
# 1   Percent of adults aged 18 years and older who ...        EDUHSGRAD
# 5   Percent of adults who achieve at least 150 min...          RACEHIS
# 6   Percent of adults aged 18 years and older who ...          RACENAA
# 7   Percent of adults aged 18 years and older who ...            EDUHS
# 8   Percent of adults who engage in no leisure-tim...          INC2535
# 9   Percent of adults aged 18 years and older who ...        AGEYR2534
# 10  Percent of adults who engage in no leisure-tim...        EDUHSGRAD
# 11  Percent of adults aged 18 years and older who ...          RACEHIS
# 13  Percent of adults who engage in no leisure-tim...        INCLESS15
# 14  Percent of adults who engage in no leisure-tim...          RACEASN
# 17  Percent of adults aged 18 years and older who ...        AGEYR5564
# 18  Percent of adults aged 18 years and older who ...          RACEOTH
# 20  Percent of adults who engage in muscle-strengt...          RACEOTH
# 22  Percent of adults who report consuming fruit l...        INCLESS15
# 24  Percent of adults aged 18 years and older who ...        AGEYR5564
# 26  Percent of adults aged 18 years and older who ...        INCLESS15
# 27  Percent of adults aged 18 years and older who ...        INCLESS15
# 29  Percent of adults who engage in no leisure-tim...        AGEYR4554
# 31  Percent of adults aged 18 years and older who ...          OVERALL
# 32  Percent of adults who engage in no leisure-tim...             MALE
#
#    StratificationCategory1 StratificationCategory2  \
# 1                      EDU               Education
# 5                     RACE          Race/Ethnicity
# 6                     RACE          Race/Ethnicity
# 7                      EDU               Education
# 8                      INC                  Income
# 9                    AGEYR             Age (years)
# 10                     EDU               Education
# 11                    RACE          Race/Ethnicity
# 13                     INC                  Income
# 14                    RACE          Race/Ethnicity
# 17                   AGEYR             Age (years)
# 18                    RACE          Race/Ethnicity
# 20                    RACE          Race/Ethnicity
# 22                     INC                  Income
# 24                   AGEYR             Age (years)
# 26                     INC                  Income
# 27                     INC                  Income
# 29                   AGEYR             Age (years)
# 31                     OVR                   Total
# 32                     GEN                  Gender
#
#                    Stratification  Data_Value
# 1            High school graduate        29.3
# 5                        Hispanic        27.4
# 6   American Indian/Alaska Native        48.5
# 7           Less than high school        31.6
# 8               $25,000 - $34,999        38.1
# 9                         25 - 34        35.2
# 10           High school graduate        30.5
# 11                       Hispanic        40.2
# 13              Less than $15,000        32.3
# 14                          Asian        15.3
# 17                        55 - 64        33.7
# 18                          Other        32.1
# 20                          Other        19.8
# 22              Less than $15,000        36.1
# 24                        55 - 64        42.0
# 26              Less than $15,000        36.1
# 27              Less than $15,000        34.5
# 29                        45 - 54        50.4
# 31                          Total        29.5
# 32                           Male        21.7

# %%
# Specify the path to your JASON configuration file
config_file_path= '/content/config.json'

#Load the JSON configuration file
with open(config_file_path, 'r') as config_file:
    config = json.load(config_file)


CONNECTION_STRING_AZURE_STORAGE = config["ConnectionString"]
CONTAINER_AZURE="obesitybehavior"
blob_name = "obesitybehavior_data_cleaned.csv"

# Conbert DataFrame to CSV
output=StringIO()
df.to_csv(output, index=False)
data = output.getvalue()
output.close()

# Create the BlobServiceClient object
blob_service_client = BlobServiceClient.from_connection_string(CONNECTION_STRING_AZURE_STORAGE)

# Get a blob client using the container name and blob name
blob_client = blob_service_client.get_blob_client(container=CONTAINER_AZURE, blob=blob_name)

# Upload the CSV data
blob_client.upload_blob(data, overwrite=True)

print(f"Uploaded {blob_name} to Azure Blob Storage in container {CONTAINER_AZURE}.")
# Out:
# Uploaded obesitybehavior_data_cleaned.csv to Azure Blob Storage in container obesitybehavior.
